# %%
# Given input 1037013 required output 1371300

arr = []
l = len(arr)
for i in range(l):
    if arr[i] == 0:
        arr = arr.replace("0","")+"0"
print(arr)
# Out:
# enter the number 102
# ['1', '0', '2']
