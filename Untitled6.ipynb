# %%
age=input()
age=int(age)
print("your age is",age)
hexage=hex(age)
print("your age in hexadecimal is ",hexage)
# Out:
#  1110
# your age is 1110
# your age in hexadecimal is  0x456

# %%
0b111
# Out:
# 7

# %%
15
# Out:
# 15

# %%
0x9ac
# Out:
# 2476

# %%
i=int('111',2)
print(i)
# Out:
# 7
