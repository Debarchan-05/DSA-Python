# %%
age = int(input("Enter the age:"))
print(age)
# Out:
# Enter the age: 21
# 21

# %%
print(type(age))
print(age)
# Out:
# <class 'int'>
# 21

# %%
num1 = int(input())
num2 = int(input())
sum = num1+num2
print("The sum is :" ,sum)
# Out:
#  14
#  15
# The sum is : 29

# %%
num1 = 12.0
num2 = 12
sum = num1+num2
print("The sum is :" ,sum)
# Out:
# The sum is : 24.0

# %%
List = "It is a sequence of heterogenous elements seperated by comma stored inside a square bracket"

# %%
list = [1,"apple",3.14]
type(list)
# Out:
# list

# %%
list = (1,"apple",3.14)
type(list)
# Out:
# tuple

# %%
for ch in "angel":
    print(ch, end=" ")
# Out:
# a n g e l

# %%
list(range(1,10,2))
# Out:
# [1, 3, 5, 7, 9]

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
range(10,5,-1)

# %%
#Armstrong Number

# %%
num = int(input("Enter a number"))
while num > 0:
    r = num % 10
    sum += pow(num , r)
    print(sum)
# Out:
# Enter a number 153
# 10744731
# 14326308
# 17907885
# 21489462
# 25071039
# 28652616
# 32234193
# 35815770
# 39397347
# 42978924
# 46560501
# 50142078
# 53723655
# 57305232
# 60886809
# 64468386
# 68049963
# 71631540
# 75213117
# 78794694
# 82376271
# 85957848
# 89539425
# 93121002
# 96702579
# 100284156
# 103865733
# 107447310
# 111028887
# 114610464
# 118192041
# 121773618
# 125355195
# 128936772
# 132518349
# 136099926
# 139681503
# 143263080
# 146844657
# 150426234
# 154007811
# 157589388
# 161170965
# 164752542
# 168334119
# 171915696
# 175497273
# 179078850
# 182660427
# 186242004
# 189823581
# 193405158
# 196986735
# 200568312
# 204149889
# 207731466
# 211313043
# 214894620
# 218476197
# 222057774
# 225639351
# 229220928
# 232802505
# 236384082
# 239965659
# 243547236
# 247128813
# 250710390
# 254291967
# 257873544
# 261455121
# 265036698
# 268618275
# 272199852
# 275781429
# 279363006
# 282944583
# 286526160
# 290107737
# 293689314
# 297270891
# 300852468
# 304434045
# ...
