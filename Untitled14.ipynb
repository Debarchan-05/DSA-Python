# %%
def find(arr)

# %%
def reverseArr(arr):
    if len(arr) <=1:
        return arr
    return arr[::-1]
arr =[1,5,7,8,9]
ans = reverseArr(arr)
print(ans)
# Out:
# [9, 8, 7, 5, 1]

# %%
def k_samll(arr,k):
    arr.sort()

# %%
def sort012(arr):
    start,mid =0,0
    end = len(arr)-1

    while mid <= end:
        if arr[mid] ==0:
            arr[start] ,arr[mid] = arr[mid],arr[start]
        elif arr[mid]==1:
            mid+=1
        else:
# Out:
#   Cell In[10], line 7
#
#     ^
# _IncompleteInputError: incomplete input

# %%
#Two pointer approach
def move_num(arr):
    if len(arr)== 0:
        return arr
    start = 0
    end = len(arr)-1
